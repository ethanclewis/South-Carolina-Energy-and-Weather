# %% [markdown]
# # Abstract

# %% [markdown]
# Summary of final Energy and Weather data frames.

# %%
# %store -r energy_by_BA
# %store -r energy_SC
# %store -r avg_weather

# %% [markdown]
# # South Carolina Total Energy

# %%
energy_SC
# Out:
#            Date Measurement Code     Measurement     MWh
# 0    2018-07-01                D          Demand  708190
# 1    2018-07-01               NG  Net Generation  705031
# 2    2018-07-01              NUC         Nuclear  277756
# 3    2018-07-01              SUN           Solar   16719
# 4    2018-07-01              WAT           Hydro    6187
# ...         ...              ...             ...     ...
# 9130 2023-07-01                D          Demand  683781
# 9131 2023-07-01               NG  Net Generation  686368
# 9132 2023-07-01              NUC         Nuclear  285400
# 9133 2023-07-01              SUN           Solar   34890
# 9134 2023-07-01              WAT           Hydro    8100
#
# [9135 rows x 4 columns]

# %% [markdown]
# # South Carolina Average Weather

# %%
avg_weather
# Out:
#             Date  Avg. Apparent Temperature (F)  Avg. Temperature at 2m (F)  \
# 0     2018-07-01                      88.824806                   80.506638
# 1     2018-07-02                      90.352264                   81.567917
# 2     2018-07-03                      90.680389                   82.779175
# 3     2018-07-04                      86.927147                   81.032707
# 4     2018-07-05                      87.815704                   80.624733
# ...          ...                            ...                         ...
# 1822  2023-06-27                      82.439423                   79.051910
# 1823  2023-06-28                      83.100731                   78.667862
# 1824  2023-06-29                      84.788788                   79.303993
# 1825  2023-06-30                      86.435852                   79.916328
# 1826  2023-07-01                      88.742973                   81.121582
#
# ...

# %% [markdown]
# # South Carolina Energy by Balancing Authority

# %%
energy_by_BA
# Out:
#             Date Balancing Authority Code  \
# 0     2018-07-01                     SCEG
# 1     2018-07-01                     SCEG
# 2     2018-07-01                     SCEG
# 3     2018-07-01                     SCEG
# 4     2018-07-01                     SCEG
# ...          ...                      ...
# 34784 2023-07-01                     CPLE
# 34785 2023-07-01                       SC
# 34786 2023-07-01                       SC
# 34787 2023-07-01                       SC
# 34788 2023-07-01                       SC
#
#                            Balancing Authority Measurement Code  \
# 0         Dominion Energy South Carolina, Inc.                D
# 1         Dominion Energy South Carolina, Inc.               NG
# 2         Dominion Energy South Carolina, Inc.              NUC
# 3         Dominion Energy South Carolina, Inc.              SUN
# 4         Dominion Energy South Carolina, Inc.              WAT
# ...                                        ...              ...
# ...
